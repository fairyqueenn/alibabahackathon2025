# %%
import pandas as pd

# %%
data = pd.read_csv('data\Panduan_Diet_Penyakit.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\rozak\AppData\Local\Temp\ipykernel_32500\1326676455.py:1: SyntaxWarning: invalid escape sequence '\P'
#   data = pd.read_csv('data\Panduan_Diet_Penyakit.csv')

# %%
data.head()
# Out:
#             Penyakit                              Pantangan  \
# 0           Diabetes        Gula, nasi putih, minuman manis
# 1         Hipertensi    Garam, makanan olahan, daging merah
# 2          Asam urat       Jeroan, seafood, kacang-kacangan
# 3  Kolesterol tinggi  Makanan berlemak, gorengan, fast food
# 4   Penyakit jantung               Garam, lemak jenuh, gula
#
#                        Makanan Rekomendasi  \
# 0  Sayur hijau, gandum utuh, ikan berlemak
# 1   Pisang, sayur hijau, susu rendah lemak
# 2           Sayuran, buah segar, air putih
# 3          Oatmeal, alpukat, minyak zaitun
# 4         Ikan, kacang-kacangan, buah beri
#
#                        Diet Rekomendasi
# 0  Rendah gula dan karbohidrat kompleks
# 1                             Diet DASH
# 2                     Diet rendah purin
# 3               Diet rendah lemak jenuh
# 4                      Diet Mediterania
